# %%
from pymongo import MongoClient

# %%
#Define connection parameters
username = 'omar'
password = 'usfomar'
database = 'training'

url = f'mongodb://{username}:{password}@localhost:27017'
#create  the connection
connection = MongoClient(url)
#list all database names
connection.list_database_names()
training = connection.training

# %%
glossary = training.mongodb_glossary

# %%
docs = [{'database':'a database contains collections'},
{'collection':'a collection stores the documents'},
{'document':'a document contains the data in the form of key value pairs.'}
]

glossary.insert_many(docs)
# Out:
# InsertManyResult([ObjectId('6915f6e59c2d56d3827079ae'), ObjectId('6915f6e59c2d56d3827079af'), ObjectId('6915f6e59c2d56d3827079b0')], acknowledged=True)

# %%
for i in glossary.find():
    print(i)
# Out:
# {'_id': ObjectId('6915f6e59c2d56d3827079ae'), 'database': 'a database contains collections'}
# {'_id': ObjectId('6915f6e59c2d56d3827079af'), 'collection': 'a collection stores the documents'}
# {'_id': ObjectId('6915f6e59c2d56d3827079b0'), 'document': 'a document contains the data in the form of key value pairs.'}

# %%
connection.close()
